# %% [markdown]
# # Stretch 03 — 画像＝配列
#
# `../../../data/4.2.07.tiff`をPillowで読み、NumPy配列にしてshape / dtypeを表示し、左上を切り取り・Bチャネルを取り出してください。

# %% [markdown]
# NumPyと、PILからImageモジュールをimportしてください。

# %% [markdown]
# 画像を`im`に読み込んでください。ここではセルを分けるためwith句は使いません。

# %% [markdown]
# 画像の形式、サイズ、モード（データフォーマット）を確認してください。

# %% [markdown]
# `im`をNumPyの配列`arr`に変換してください。

# %% [markdown]
# `arr`の形（行数列数）とデータ型を確認してください。

# %% [markdown]
# 左上1/4（縦1/2、横1/2）の部分を切り取って`arr_cropped`に入れ、形を確認してください。

# %% [markdown]
# NumPy配列からPIL画像に戻して表示してください。

# %% [markdown]
# `arr`のBチャネルを抽出して配列の形を確認してください。

# %% [markdown]
# `im`をクローズしてください。なお、通常はwith句を使うのでこの処理は不要です。
