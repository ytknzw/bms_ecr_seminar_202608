# %% [markdown]
# # 正解 — Must 01 — 線形回帰
#
# `Culmen_Length`と`Flipper_Length`から`Body_Mass`を`LinearRegression()`で予測し、テストデータのMSEとMAPEを表示してください。
#
# `python/` に入って実行してください（データは `../../../data/`）。

# %% [markdown]
# ## 準備

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import train_test_split

df = pd.read_parquet("../../../data/penguins.parquet").dropna(
    subset=["Culmen_Length", "Flipper_Length", "Body_Mass"]  # 欠損を除去
)

# %% [markdown]
# 特徴量`X`（`Culmen_Length`, `Flipper_Length`）と目的変数`y`（`Body_Mass`）を用意してください。

# %%
X = df.loc[:, ["Culmen_Length", "Flipper_Length"]]
y = df.loc[:, "Body_Mass"]

# %% [markdown]
# `train_test_split()`関数で学習データとテストデータに分けてください。比率は7:3、乱数シードは123とします。

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=123
)

# %% [markdown]
# `LinearRegression()`でモデルを構築してください。

# %%
model_reg = LinearRegression()
model_reg.fit(X_train, y_train)

# %% [markdown]
# テストデータで予測してください。

# %%
y_predicted = model_reg.predict(X_test)

# %% [markdown]
# テストデータについてMSEとMAPEを表示してください。

# %%
print(f"{mean_squared_error(y_test, y_predicted)=}")
print(f"{mean_absolute_percentage_error(y_test, y_predicted)=}")
