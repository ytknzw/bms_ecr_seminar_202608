# %% [markdown]
# # Must 03 — 棒グラフ
#
# 種と島ごとの平均体重の棒グラフを描いてください。

# %% [markdown]
# ## 準備（データ読み込み）

# %%
import pandas as pd
import plotly.express as px

df = pd.read_parquet("../../../data/penguins.parquet")

# %% [markdown]
# 種と島の組ごとの平均体重

# %%
df_avg_weight_island = df.groupby(
    ["Species_short", "Island"], as_index=False, observed=True
)["Body_Mass"].mean()

# %% [markdown]
# ## TODO
#
# 種と島ごとの平均体重の棒グラフを描いてください。各棒は色と模様を変えて（Dark2、`pattern_shape`）、横に並べてください。
